# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk

# Download required NLTK data
nltk.download('wordnet')
nltk.download('omw-1.4')

# Example 1: Using PorterStemmer
stemmer = PorterStemmer()
words = ['running', 'runs', 'ran', 'easily', 'fairly']
stemmed = [stemmer.stem(word) for word in words]
print("Stemming:", stemmed)

# Example 2: Using WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in words]
print("Lemmatization:", lemmatized)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\leekhithadb\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\leekhithadb\AppData\Roaming\nltk_data...
# Stemming: ['run', 'run', 'ran', 'easili', 'fairli']
# Lemmatization: ['running', 'run', 'ran', 'easily', 'fairly']
